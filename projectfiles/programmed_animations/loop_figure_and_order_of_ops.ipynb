# %%
import matplotlib.pyplot as plt
from matplotlib import patches, rc, rcParams, lines, patheffects
from matplotlib.animation import FuncAnimation
import numpy as np
from tqdm import tqdm
from matplotlib.patches import Rectangle
plt.xkcd()
from IPython.display import display, clear_output, Video
from random import random
import matplotlib.patches as patches

# %%
# plt.close('all')
fig, ax = plt.subplots(figsize=(8, 8))
i=0

plt.xlim([0, 50]) 
plt.ylim([0, 50]) 
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.set_xticks([])
ax.set_yticks([])
#plt.grid(True,linestyle='-',color='black',lw=1,which='both')

pad = 14
bg_pad = 1
txt_h = 1.2
txt_and_pad = txt_h + 2*bg_pad
alpha = 0.25

x,y = 25,47
y_step = txt_and_pad*2.2
y_interm_step = y_step*0.75

plt.text(x,y, "max(sqrt(number_a-1)*2, min(number_b, 2))", color='black',
         horizontalalignment='center',
         #verticalalignment='center',
         bbox=dict(facecolor='none', edgecolor='C0', pad=pad, lineWidth=2)
        )

# save
i+=1
#plt.savefig("calc_tree_%05d.png"%i,dpi=300,bbox_inches='tight')
plt.savefig("calc_tree_%05d.svg"%i,dpi=300,bbox_inches='tight')

rect = Rectangle((27.5, y-bg_pad), 13, txt_and_pad, facecolor ='C1',linewidth=1,edgecolor='none',alpha=alpha) 
ax.add_patch(rect)

# save
i+=1
#plt.savefig("calc_tree_%05d.png"%i,dpi=300,bbox_inches='tight')
plt.savefig("calc_tree_%05d.svg"%i,dpi=300,bbox_inches='tight')

y -= y_interm_step

plt.arrow(x+10, y+y_interm_step/2+1, 0, -y_interm_step,
          linewidth=2,
          head_width=1, head_length=1, overhang=1, ec='C1',length_includes_head=True)

# save
i+=1
#plt.savefig("calc_tree_%05d.png"%i,dpi=300,bbox_inches='tight')
plt.savefig("calc_tree_%05d.svg"%i,dpi=300,bbox_inches='tight')

plt.text(x+10+6,y, "number_b = 7", color='black',
         horizontalalignment='center',
         #verticalalignment='center',
         #bbox=dict(facecolor='none', edgecolor='C1', pad=pad, lineWidth=2)
        )

# save 
i+=1
#plt.savefig("calc_tree_%05d.png"%i,dpi=300,bbox_inches='tight')
plt.savefig("calc_tree_%05d.svg"%i,dpi=300,bbox_inches='tight')

y -= y_interm_step

plt.text(x+10,y, "min(7, 2)", color='black',
         horizontalalignment='center',
         #verticalalignment='center',
         bbox=dict(facecolor='none', edgecolor='C1', pad=pad, lineWidth=2)
        )

# save
i+=1
#plt.savefig("calc_tree_%05d.png"%i,dpi=300,bbox_inches='tight')
plt.savefig("calc_tree_%05d.svg"%i,dpi=300,bbox_inches='tight')

plt.text(x+17,y, "= 2", color='black',
         horizontalalignment='center',
         #verticalalignment='center',
         #bbox=dict(facecolor='none', edgecolor='C1', pad=pad, lineWidth=2)
        )

# save 
i+=1
#plt.savefig("calc_tree_%05d.png"%i,dpi=300,bbox_inches='tight')
plt.savefig("calc_tree_%05d.svg"%i,dpi=300,bbox_inches='tight')

y -= y_step

plt.arrow(x+4, y+y_interm_step*1.5+y_step, 0, -(y_interm_step*0.8+y_step),
          linewidth=2,
          head_width=1, head_length=1, overhang=1, ec='C1',length_includes_head=True)

# save
i+=1
#plt.savefig("calc_tree_%05d.png"%i,dpi=300,bbox_inches='tight')
plt.savefig("calc_tree_%05d.svg"%i,dpi=300,bbox_inches='tight')

plt.text(x,y, "max(sqrt(number_a-1)*2,  2  )", color='black',
         horizontalalignment='center',
         #verticalalignment='center',
         bbox=dict(facecolor='none', edgecolor='C0', pad=pad, lineWidth=2)
        )

rect = Rectangle((33, y-bg_pad), 2, txt_and_pad, facecolor ='C1',linewidth=1,edgecolor='none',alpha=alpha) 
ax.add_patch(rect)

# save
i+=1
#plt.savefig("calc_tree_%05d.png"%i,dpi=300,bbox_inches='tight')
plt.savefig("calc_tree_%05d.svg"%i,dpi=300,bbox_inches='tight')

rect = Rectangle((17.5, y-bg_pad), 15, txt_and_pad, facecolor ='C2',linewidth=1,edgecolor='none',alpha=alpha) 
ax.add_patch(rect)

# save
i+=1
#plt.savefig("calc_tree_%05d.png"%i,dpi=300,bbox_inches='tight')
plt.savefig("calc_tree_%05d.svg"%i,dpi=300,bbox_inches='tight')

y -= y_interm_step

plt.arrow(x, y+y_interm_step/2+1, 0, -y_interm_step,
          linewidth=2,
          head_width=1, head_length=1, overhang=1, ec='C2',length_includes_head=True)

# save
i+=1
#plt.savefig("calc_tree_%05d.png"%i,dpi=300,bbox_inches='tight')
plt.savefig("calc_tree_%05d.svg"%i,dpi=300,bbox_inches='tight')

plt.text(x+6,y+txt_and_pad*0.4, "number_a = 5", color='black',
         horizontalalignment='center',
         #verticalalignment='center',
         #bbox=dict(facecolor='none', edgecolor='C1', pad=pad, lineWidth=2)
        )

# save 
i+=1
#plt.savefig("calc_tree_%05d.png"%i,dpi=300,bbox_inches='tight')
plt.savefig("calc_tree_%05d.svg"%i,dpi=300,bbox_inches='tight')

plt.text(x+6,y-txt_and_pad*0.4, "  number_a-1 = 4", color='black',
         horizontalalignment='center',
         #verticalalignment='center',
         #bbox=dict(facecolor='none', edgecolor='C1', pad=pad, lineWidth=2)
        )


# save
i+=1
#plt.savefig("calc_tree_%05d.png"%i,dpi=300,bbox_inches='tight')
plt.savefig("calc_tree_%05d.svg"%i,dpi=300,bbox_inches='tight')

y -= y_interm_step

plt.text(x,y, "sqrt(4)*2", color='black',
         horizontalalignment='center',
         #verticalalignment='center',
         bbox=dict(facecolor='none', edgecolor='C2', pad=pad, lineWidth=2)
        )

# save
i+=1
#plt.savefig("calc_tree_%05d.png"%i,dpi=300,bbox_inches='tight')
plt.savefig("calc_tree_%05d.svg"%i,dpi=300,bbox_inches='tight')

plt.text(x+8,y, "= 2*2", color='black',
         horizontalalignment='center',
         #verticalalignment='center',
         #bbox=dict(facecolor='none', edgecolor='C1', pad=pad, lineWidth=2)
        )

# save
i+=1
#plt.savefig("calc_tree_%05d.png"%i,dpi=300,bbox_inches='tight')
plt.savefig("calc_tree_%05d.svg"%i,dpi=300,bbox_inches='tight')

plt.text(x+12,y, "= 4", color='black',
         horizontalalignment='center',
         #verticalalignment='center',
         #bbox=dict(facecolor='none', edgecolor='C1', pad=pad, lineWidth=2)
        )

# save 
i+=1
#plt.savefig("calc_tree_%05d.png"%i,dpi=300,bbox_inches='tight')
plt.savefig("calc_tree_%05d.svg"%i,dpi=300,bbox_inches='tight')

y -= y_step

plt.arrow(x-6, y+y_interm_step*1.5+y_step, 0, -(y_interm_step*0.8+y_step),
          linewidth=2,
          head_width=1, head_length=1, overhang=1, ec='C2',length_includes_head=True)

# save
i+=1
#plt.savefig("calc_tree_%05d.png"%i,dpi=300,bbox_inches='tight')
plt.savefig("calc_tree_%05d.svg"%i,dpi=300,bbox_inches='tight')

plt.text(x,y, "max(  4  ,  2  )", color='black',
         horizontalalignment='center',
         #verticalalignment='center',
         bbox=dict(facecolor='none', edgecolor='C0', pad=pad, lineWidth=2)
        )

rect = Rectangle((27, y-bg_pad), 2, txt_and_pad, facecolor ='C1',linewidth=1,edgecolor='none',alpha=alpha) 
ax.add_patch(rect)
rect = Rectangle((24, y-bg_pad), 2, txt_and_pad, facecolor ='C2',linewidth=1,edgecolor='none',alpha=alpha) 
ax.add_patch(rect)

# save 
i+=1
#plt.savefig("calc_tree_%05d.png"%i,dpi=300,bbox_inches='tight')
plt.savefig("calc_tree_%05d.svg"%i,dpi=300,bbox_inches='tight')

y -= y_interm_step

plt.arrow(x, y+y_interm_step/2+1, 0, -y_interm_step,
          linewidth=2,
          head_width=1, head_length=1, overhang=1, ec='black',length_includes_head=True)

# save
i+=1
#plt.savefig("calc_tree_%05d.png"%i,dpi=300,bbox_inches='tight')
plt.savefig("calc_tree_%05d.svg"%i,dpi=300,bbox_inches='tight')

y -= y_interm_step

plt.text(x,y, "4", color='black',
         horizontalalignment='center',
         #verticalalignment='center',
         bbox=dict(facecolor='none', edgecolor='black', pad=pad, lineWidth=2)
        )


i+=1
#plt.savefig("calc_tree_%05d.png"%i,dpi=300,bbox_inches='tight')
plt.savefig("calc_tree_%05d.svg"%i,dpi=300,bbox_inches='tight')

#plt.savefig("calc_tree.png",dpi=600,bbox_inches='tight')
plt.savefig("calc_tree.svg",dpi=600,bbox_inches='tight')
i
# Out:
# 19

# %%
# !for f in *.svg; echo $f; flatpak run org.inkscape.Inkscape --export-type="png" --export-dpi=300 $f; end
# Out:
# calc_tree.svg
# Background RRGGBBAA: ffffff00
# Area 0:0:625.067:609.707 exported to 1953 x 1905 pixels (300 dpi)
# calc_tree_00001.svg
# Background RRGGBBAA: ffffff00
# Area 0:0:625.067:609.707 exported to 1953 x 1905 pixels (300 dpi)
# calc_tree_00002.svg
# Background RRGGBBAA: ffffff00
# Area 0:0:625.067:609.707 exported to 1953 x 1905 pixels (300 dpi)
# calc_tree_00003.svg
# Background RRGGBBAA: ffffff00
# Area 0:0:625.067:609.707 exported to 1953 x 1905 pixels (300 dpi)
# calc_tree_00004.svg
# Background RRGGBBAA: ffffff00
# Area 0:0:625.067:609.707 exported to 1953 x 1905 pixels (300 dpi)
# calc_tree_00005.svg
# Background RRGGBBAA: ffffff00
# Area 0:0:625.067:609.707 exported to 1953 x 1905 pixels (300 dpi)
# calc_tree_00006.svg
# Background RRGGBBAA: ffffff00
# Area 0:0:625.067:609.707 exported to 1953 x 1905 pixels (300 dpi)
# calc_tree_00007.svg
# Background RRGGBBAA: ffffff00
# Area 0:0:625.067:609.707 exported to 1953 x 1905 pixels (300 dpi)
# calc_tree_00008.svg
#
# ...

# %%
# !cp calc_tree_00019.png calc_tree_00020.png 
# !cp calc_tree_00019.png calc_tree_00021.png 
# !cp calc_tree_00019.png calc_tree_00022.png

# %%
# !ffmpeg -y -framerate 1 -i 'calc_tree_%05d.png' -vf "scale=trunc(iw/2)*2:trunc(ih/2)*2" -c:v libx264 -pix_fmt yuv420p -crf 20 calc_tree.mp4
# Out:
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
# ...

# %%
plt.close('all')
fig, ax = plt.subplots(figsize=(8, 4))

plt.xlim([0, 50]) 
plt.ylim([0, 50]) 
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.set_xticks([])
ax.set_yticks([])
#plt.grid(True,linestyle='-',color='black',lw=1,which='both')

pad = 14
bg_pad = 1
txt_h = 1.2
txt_and_pad = txt_h + 2*bg_pad
alpha = 0.25

x,y = 15,25
y_step = txt_and_pad*2.2
y_interm_step = y_step*0.75


plt.text(x-10,y, "turn on", color='black',
         #horizontalalignment='center',
         #verticalalignment='center',
         #bbox=dict(facecolor='none', edgecolor='C0', pad=pad, lineWidth=2)
        )

plt.arrow(x-4.2, y+1, 4.5, 0,
          linewidth=2,
          head_width=2, head_length=1, overhang=1, ec='black',length_includes_head=True)


plt.text(x+3,y, "setup()", color='black',
         #horizontalalignment='center',
         #verticalalignment='center',
         bbox=dict(facecolor='none', edgecolor='C0', pad=pad, lineWidth=2)
        )

plt.arrow(x+10, y+1, 7, 0,
          linewidth=2,
          head_width=2, head_length=1, overhang=1, ec='C0',length_includes_head=True)

plt.text(x+19,y, "loop()", color='black',
         #horizontalalignment='center',
         #verticalalignment='center',
         bbox=dict(facecolor='none', edgecolor='C1', pad=pad, lineWidth=2)
        )

t = 30
a = patches.Arc((x+25,y+1),10,25,angle=0,theta1=270-t,theta2=90+t,
                linewidth=2,
                color='C1'
               )
plt.gca().add_patch(a)

plt.arrow(x+20.8,y+7, 0, -0.01,
          linewidth=2,
          zorder=100,
          head_width=1, head_length=1, overhang=1, ec='C1',length_includes_head=True)

plt.savefig("start_setup_loop.svg",dpi=600,bbox_inches='tight')

# %%
plt.close('all')
fig, ax = plt.subplots(figsize=(8, 4))

plt.xlim([0, 50]) 
plt.ylim([0, 50]) 
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.set_xticks([])
ax.set_yticks([])
#plt.grid(True,linestyle='-',color='black',lw=1,which='both')

pad = 14
bg_pad = 1
txt_h = 1.2
txt_and_pad = txt_h + 2*bg_pad
alpha = 0.25

x,y = 10,35
y_step = txt_and_pad*2.2
y_interm_step = y_step*0.75


plt.text(x-10,y, "turn on", color='black',
         #horizontalalignment='center',
         #verticalalignment='center',
         #bbox=dict(facecolor='none', edgecolor='C0', pad=pad, lineWidth=2)
        )

plt.arrow(x-4.2, y+1, 4.5, 0,
          linewidth=2,
          head_width=2, head_length=1, overhang=1, ec='black',length_includes_head=True)


plt.text(x+3,y, "setup()", color='black',
         #horizontalalignment='center',
         #verticalalignment='center',
         bbox=dict(facecolor='none', edgecolor='C0', pad=pad, lineWidth=2)
        )

plt.arrow(x+10, y+1, 5, 0,
          linewidth=2,
          head_width=2, head_length=1, overhang=1, ec='C0',length_includes_head=True)

plt.text(x+16,y, "loop()", color='black',
         #horizontalalignment='center',
         #verticalalignment='center',
         #bbox=dict(facecolor='none', edgecolor='C1', pad=pad, lineWidth=2)
        )

plt.arrow(x+16+5,y-1, 11/2.5, -10/2.5,
          linewidth=1,
          linestyle='-',
          zorder=100,
          head_width=1, head_length=1, overhang=1, ec='C1',length_includes_head=True)


plt.text(x+27,y-10, "light up which_LED", color='black',
         horizontalalignment='center',
         fontsize=12,
         #verticalalignment='center',
         #bbox=dict(facecolor='none', edgecolor='C1', pad=pad, lineWidth=2)
        )

plt.arrow(x+27,y-12, 0, -4,
          linewidth=1,
          linestyle='-',
          zorder=100,
          head_width=1, head_length=1, overhang=1, ec='C1',length_includes_head=True)


plt.text(x+27,y-20, "increment which_LED", color='black',
         horizontalalignment='center',
         fontsize=12,
         #verticalalignment='center',
         #bbox=dict(facecolor='none', edgecolor='C1', pad=pad, lineWidth=2)
        )


rx, ry = 20,28
rect = Rectangle((x+15, y-ry+5), rx, ry, facecolor ='none',linewidth=2,edgecolor='C1') 
ax.add_patch(rect)


t = 28
a = patches.Arc((x+29,y-5),20,35,angle=0,theta1=0,theta2=90+t,
                linewidth=2,
                color='C1'
               )
plt.gca().add_patch(a)
a = patches.Arc((x+31.5,y-5),15,59,angle=0,theta1=270-t/2,theta2=0,
                linewidth=2,
                color='C1'
               )
plt.gca().add_patch(a)

plt.arrow(x+21.8,y+7, -0.005, -0.01,
          linewidth=2,
          zorder=100,
          head_width=1, head_length=1, overhang=1, ec='C1',length_includes_head=True)


plt.savefig("start_setup_loop_anim.svg",dpi=600,bbox_inches='tight')

# %%
# !for f in start_*.svg; echo $f; flatpak run org.inkscape.Inkscape --export-type="png" --export-dpi=300 $f; end
# Out:
# start_setup_loop.svg
# Background RRGGBBAA: ffffff00
# Area 0:0:625.067:319.787 exported to 1953 x 999 pixels (300 dpi)
# start_setup_loop_anim.svg
# Background RRGGBBAA: ffffff00
# Area 0:0:625.067:319.787 exported to 1953 x 999 pixels (300 dpi)
