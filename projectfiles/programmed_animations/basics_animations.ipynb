# %%
import matplotlib.pyplot as plt
from matplotlib import patches, rc, rcParams, lines, patheffects
from matplotlib.animation import FuncAnimation
import numpy as np
from tqdm import tqdm
from matplotlib.patches import Rectangle
plt.xkcd()
from IPython.display import display, clear_output, Video
from random import random

# %%
fig, ax = plt.subplots(figsize=(8, 8))

# Draw first frame
rect2 = Rectangle((10, 40), 30, 5, facecolor ='red',linewidth=1,edgecolor='black') 
ax.add_patch(rect2) 
plt.text(25,42, "SpinWheel: OFF ", color='black',horizontalalignment='center')
plt.xlim([0, 50]) 
plt.ylim([0, 50]) 
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.set_xticks([])
ax.set_yticks([])

plt.savefig("progLoop_00000.png",dpi=300,bbox_inches='tight')
plt.savefig("progLoop_00001.png",dpi=300,bbox_inches='tight')
plt.savefig("progLoop_00002.png",dpi=300,bbox_inches='tight')

# Draw with SpinWheel on
plt.close('all')
fig, ax = plt.subplots(figsize=(8, 8))


rect2 = Rectangle((10, 40), 30, 5, facecolor ='green',linewidth=1,edgecolor='black') 
ax.add_patch(rect2) 
plt.text(25,42, "SpinWheel: ON ", color='black',horizontalalignment='center')
plt.xlim([0, 50]) 
plt.ylim([0, 50]) 
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.set_xticks([])
ax.set_yticks([])
plt.savefig("progLoop_00003.png",dpi=300,bbox_inches='tight')



# Add setup
plt.text(5,32.5, "set_up()", color='black',horizontalalignment='center',bbox=dict(facecolor='none', edgecolor='C1', pad=15.0, lineWidth=2))
plt.savefig("progLoop_00004.png",dpi=300,bbox_inches='tight')



# Add loop
x = 0
y = 30
for i in range(0,29):
    x = x+10;
    if (x > 40):
        x = 0
        y = y-6
    plt.text(x+5,y+2.5, "  loop()  ", color='black',horizontalalignment='center',bbox=dict(facecolor='none', edgecolor='C0', pad=15.0, lineWidth=2))
    plt.savefig("progLoop_%05d.png"%(i+4.0),dpi=300,bbox_inches='tight')


# Add random ones
for i in range(0,20):
    x = random()*40
    y = random()*25
    plt.text(x+5,y+2.5, "  loop()  ", color='black',horizontalalignment='center',bbox=dict(facecolor='white', edgecolor='C0', pad=15.0, lineWidth=2))
    plt.savefig("progLoop_%05d.png"%(i+32.0),dpi=300,bbox_inches='tight')

# %%
# !./ffmpeg -framerate 5 -i 'progLoop_%05d.png' -vf "scale=trunc(iw/2)*2:trunc(ih/2)*2" -c:v libx264 -pix_fmt yuv420p -crf 20 setup_loop.mp4
# Out:
# ffmpeg version N-98460-g6f84e92172-tessus  https://evermeet.cx/ffmpeg/  Copyright (c) 2000-2020 the FFmpeg developers
#   built with Apple clang version 11.0.0 (clang-1100.0.33.17)
#   configuration: --cc=/usr/bin/clang --prefix=/opt/ffmpeg --extra-version=tessus --enable-avisynth --enable-fontconfig --enable-gpl --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libfreetype --enable-libgsm --enable-libmodplug --enable-libmp3lame --enable-libmysofa --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenh264 --enable-libopenjpeg --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvmaf --enable-libvo-amrwbenc --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-version3 --pkg-config-flags=--static --disable-ffplay
#   libavutil      56. 55.100 / 56. 55.100
#   libavcodec     58. 95.100 / 58. 95.100
#   libavformat    58. 48.100 / 58. 48.100
#   libavdevice    58. 11.101 / 58. 11.101
#   libavfilter     7. 87.100 /  7. 87.100
#   libswscale      5.  8.100 /  5.  8.100
#   libswresample   3.  8.100 /  3.  8.100
#   libpostproc    55.  8.100 / 55.  8.100
# Input #0, image2, from 'progLoop_%05d.png':
#   Duration: 00:00:10.40, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 1953x1905 [SAR 11811:11811 DAR 651:635], 5 fps, 5 tbr, 5 tbn, 5 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x7f8e9800e200] using SAR=1/1
# [libx264 @ 0x7f8e9800e200] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x7f8e9800e200] profile High, level 5.0, 4:2:0, 8-bit
# [libx264 @ 0x7f8e9800e200] 264 - core 161 r3015 4c2aafd - H.264/MPEG-4 AVC codec - Copyleft 2003-2020 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=5 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=20.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'setup_loop.mp4':
#   Metadata:
#     encoder         : Lavf58.48.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1952x1904 [SAR 77469:77470 DAR 651:635], q=-1--1, 5 fps, 10240 tbn, 5 tbc
#     Metadata:
#       encoder         : Lavc58.95.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   52 fps=6.8 q=-1.0 Lsize=     362kB time=00:00:09.80 bitrate= 302.9kbits/s speed=1.29x
# video:361kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.400706%
# [libx264 @ 0x7f8e9800e200] frame I:1     Avg QP:11.29  size: 24523
# [libx264 @ 0x7f8e9800e200] frame P:14    Avg QP:12.61  size: 23405
# [libx264 @ 0x7f8e9800e200] frame B:37    Avg QP: 6.01  size:   452
# [libx264 @ 0x7f8e9800e200] consecutive B-frames:  3.8%  3.8%  0.0% 92.3%
# [libx264 @ 0x7f8e9800e200] mb I  I16..4: 13.8% 83.6%  2.7%
# [libx264 @ 0x7f8e9800e200] mb P  I16..4:  0.6%  0.6%  2.8%  P16..4:  0.8%  0.3%  0.2%  0.0%  0.0%    skip:94.7%
# [libx264 @ 0x7f8e9800e200] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  2.2%  0.0%  0.0%  direct: 0.0%  skip:97.7%  L0:55.3% L1:44.6% BI: 0.1%
# [libx264 @ 0x7f8e9800e200] 8x8 transform intra:58.2% inter:30.3%
# [libx264 @ 0x7f8e9800e200] coded y,uvDC,uvAC intra: 20.4% 20.8% 20.6% inter: 0.1% 0.2% 0.1%
# [libx264 @ 0x7f8e9800e200] i16 v,h,dc,p: 60% 36%  4%  0%
# [libx264 @ 0x7f8e9800e200] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 73%  2% 25%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x7f8e9800e200] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 37% 37% 13%  2%  2%  2%  2%  3%  2%
# [libx264 @ 0x7f8e9800e200] i8c dc,h,v,p: 78% 14%  7%  0%
# [libx264 @ 0x7f8e9800e200] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x7f8e9800e200] ref P L0: 79.7%  2.7% 13.8%  3.8%
# [libx264 @ 0x7f8e9800e200] ref B L0: 68.4% 28.4%  3.2%
# [libx264 @ 0x7f8e9800e200] ref B L1: 99.0%  1.0%
# [libx264 @ 0x7f8e9800e200] kb/s:283.78

# %%
fig, ax = plt.subplots(figsize=(11, 8))

# Draw first frame
rect2 = Rectangle((10, 40), 30, 5, facecolor ='red',linewidth=1,edgecolor='black') 
ax.add_patch(rect2) 
plt.text(25,42, "SpinWheel: OFF ", color='black',horizontalalignment='center')
plt.xlim([0, 70]) 
plt.ylim([0, 50]) 
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.set_xticks([])
ax.set_yticks([])

plt.savefig("progLoop2_00000.png",dpi=300,bbox_inches='tight')
plt.savefig("progLoop2_00001.png",dpi=300,bbox_inches='tight')
plt.savefig("progLoop2_00002.png",dpi=300,bbox_inches='tight')

# Draw with SpinWheel on
plt.close('all')
fig, ax = plt.subplots(figsize=(11, 8))


rect2 = Rectangle((10, 40), 30, 5, facecolor ='green',linewidth=1,edgecolor='black') 
ax.add_patch(rect2) 
plt.text(25,42, "SpinWheel: ON ", color='black',horizontalalignment='center')
plt.xlim([0, 70]) 
plt.ylim([0, 50]) 
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.set_xticks([])
ax.set_yticks([])
plt.savefig("progLoop2_00003.png",dpi=300,bbox_inches='tight')



# Add setup
plt.text(5,32.5, "set_up()", color='black',horizontalalignment='center',bbox=dict(facecolor='none', edgecolor='C1', pad=15.0, lineWidth=2))
plt.savefig("progLoop2_00004.png",dpi=300,bbox_inches='tight')

# Add setup
rect2 = Rectangle((55, 20), 10, 8, facecolor ='white',linewidth=1,edgecolor='black') 
ax.add_patch(rect2) 
plt.text(60,25, "brightness", color='black',horizontalalignment='center')
plt.text(60,22, "0", color='black',horizontalalignment='center')


plt.savefig("progLoop2_00005.png",dpi=300,bbox_inches='tight')



# Add loop
x = 0
y = 30
for i in range(0,29): #29
    x = x+10;
    if (x > 40):
        x = 0
        y = y-6
    plt.text(x+5,y+2.5, "  loop()  ", color='black',horizontalalignment='center',bbox=dict(facecolor='none', edgecolor='C0', pad=15.0, lineWidth=2))
    rect2 = Rectangle((55, 20), 10, 8, facecolor ='white',linewidth=1,edgecolor='black') 
    ax.add_patch(rect2) 
    plt.text(60,25, "brightness", color='black',horizontalalignment='center',bbox=dict(facecolor='white', edgecolor='none', pad=3.0))
    plt.text(60,22, i+1, color='black',horizontalalignment='center',bbox=dict(facecolor='white', edgecolor='none', pad=3.0))
    plt.savefig("progLoop2_%05d.png"%(i+5.0),dpi=300,bbox_inches='tight')


# # Add random ones
# for i in range(0,20):
#     x = random()*40
#     y = random()*25
#     plt.text(x+5,y+2.5, "  loop()  ", color='black',horizontalalignment='center',bbox=dict(facecolor='white', edgecolor='C0', pad=15.0, lineWidth=2))
#    # plt.savefig("progLoop2_%05d.png"%(i+32.0),dpi=300,bbox_inches='tight')

# %%
# !./ffmpeg -framerate 5 -i 'progLoop2_%05d.png' -vf "scale=trunc(iw/2)*2:trunc(ih/2)*2" -c:v libx264 -pix_fmt yuv420p -crf 20 brightness_loop.mp4
# Out:
# ffmpeg version N-98460-g6f84e92172-tessus  https://evermeet.cx/ffmpeg/  Copyright (c) 2000-2020 the FFmpeg developers
#   built with Apple clang version 11.0.0 (clang-1100.0.33.17)
#   configuration: --cc=/usr/bin/clang --prefix=/opt/ffmpeg --extra-version=tessus --enable-avisynth --enable-fontconfig --enable-gpl --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libfreetype --enable-libgsm --enable-libmodplug --enable-libmp3lame --enable-libmysofa --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenh264 --enable-libopenjpeg --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvmaf --enable-libvo-amrwbenc --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-version3 --pkg-config-flags=--static --disable-ffplay
#   libavutil      56. 55.100 / 56. 55.100
#   libavcodec     58. 95.100 / 58. 95.100
#   libavformat    58. 48.100 / 58. 48.100
#   libavdevice    58. 11.101 / 58. 11.101
#   libavfilter     7. 87.100 /  7. 87.100
#   libswscale      5.  8.100 /  5.  8.100
#   libswresample   3.  8.100 /  3.  8.100
#   libpostproc    55.  8.100 / 55.  8.100
# Input #0, image2, from 'progLoop2_%05d.png':
#   Duration: 00:00:06.80, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 2650x1905 [SAR 11811:11811 DAR 530:381], 5 fps, 5 tbr, 5 tbn, 5 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x7f94f6813400] using SAR=1904/1905
# [libx264 @ 0x7f94f6813400] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x7f94f6813400] profile High, level 5.0, 4:2:0, 8-bit
# [libx264 @ 0x7f94f6813400] 264 - core 161 r3015 4c2aafd - H.264/MPEG-4 AVC codec - Copyleft 2003-2020 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=5 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=20.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'brightness_loop.mp4':
#   Metadata:
#     encoder         : Lavf58.48.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 2650x1904 [SAR 1904:1905 DAR 530:381], q=-1--1, 5 fps, 10240 tbn, 5 tbc
#     Metadata:
#       encoder         : Lavc58.95.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   34 fps=3.4 q=-1.0 Lsize=     250kB time=00:00:06.20 bitrate= 330.0kbits/s speed=0.627x
# video:249kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.495909%
# [libx264 @ 0x7f94f6813400] frame I:1     Avg QP:14.61  size: 23718
# [libx264 @ 0x7f94f6813400] frame P:9     Avg QP:13.69  size: 23128
# [libx264 @ 0x7f94f6813400] frame B:24    Avg QP:13.04  size:   914
# [libx264 @ 0x7f94f6813400] consecutive B-frames:  2.9%  5.9%  8.8% 82.4%
# [libx264 @ 0x7f94f6813400] mb I  I16..4: 14.2% 84.0%  1.8%
# [libx264 @ 0x7f94f6813400] mb P  I16..4:  0.4%  0.2%  2.2%  P16..4:  0.6%  0.1%  0.1%  0.0%  0.0%    skip:96.4%
# [libx264 @ 0x7f94f6813400] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  2.0%  0.1%  0.0%  direct: 0.0%  skip:97.9%  L0:52.0% L1:47.7% BI: 0.3%
# [libx264 @ 0x7f94f6813400] 8x8 transform intra:68.3% inter:27.3%
# [libx264 @ 0x7f94f6813400] coded y,uvDC,uvAC intra: 13.6% 13.6% 13.5% inter: 0.1% 0.1% 0.1%
# [libx264 @ 0x7f94f6813400] i16 v,h,dc,p: 64% 32%  5%  0%
# [libx264 @ 0x7f94f6813400] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 43% 39% 18%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x7f94f6813400] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 35% 38% 16%  2%  2%  2%  2%  2%  2%
# [libx264 @ 0x7f94f6813400] i8c dc,h,v,p: 86% 10%  4%  0%
# [libx264 @ 0x7f94f6813400] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x7f94f6813400] ref P L0: 73.0%  2.8% 21.5%  2.7%
# [libx264 @ 0x7f94f6813400] ref B L0: 66.9% 27.5%  5.6%
# [libx264 @ 0x7f94f6813400] ref B L1: 98.0%  2.0%
# [libx264 @ 0x7f94f6813400] kb/s:298.58
